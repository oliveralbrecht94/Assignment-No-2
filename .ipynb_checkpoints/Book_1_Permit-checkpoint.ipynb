# %% [markdown]
# # Task San Fransisco Permit

# %% [markdown]
# ## Task A Cleaning
# - Download the Building_Permits.csv from Kaggle
# - Clean the San Francisco Building permit dataset
# - Use imputation were necessary

# %%
import numpy as np
import pandas as pd

# %%
# read in the San Francisco building permits data
sfPermits = pd.read_csv("./Building_Permits.csv")

# set seed for reproducibility
np.random.seed(0)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-8-c3b7a7e8cd05> in <module>
#       1 # read in the San Francisco building permits data
# ----> 2 sfPermits = pd.read_csv("./Building_Permits.csv")
#       3
#       4 # set seed for reproducibility
#       5 np.random.seed(0)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     700                     skip_blank_lines=skip_blank_lines)
#     701
# --> 702         return _read(filepath_or_buffer, kwds)
#     703
#     704     parser_f.__name__ = name
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     427
#     428     # Create the parser.
# --> 429     parser = TextFileReader(filepath_or_buffer, **kwds)
#     430
#     431     if chunksize or iterator:
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, f, engine, **kwds)
#     893             self.options['has_index_names'] = kwds['has_index_names']
#     894
# --> 895         self._make_engine(self.engine)
#     896
#     897     def close(self):
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\io\parsers.py in _make_engine(self, engine)
#    1120     def _make_engine(self, engine='c'):
#    1121         if engine == 'c':
# -> 1122             self._engine = CParserWrapper(self.f, **self.options)
#    1123         else:
#    1124             if engine == 'python':
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, src, **kwds)
#    1851         kwds['usecols'] = self.usecols
#    1852
# -> 1853         self._reader = parsers.TextReader(src, **kwds)
#    1854         self.unnamed_cols = self._reader.unnamed_cols
#    1855
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] File b'./Building_Permits.csv' does not exist: b'./Building_Permits.csv'

# %%
sfPermits.sample(5)

# %%
# Calculate total number of cells in dataframe
totalCells = np.product(sfPermits.shape)

# Count number of missing values per column
missingCount = sfPermits.isnull().sum()

# Calculate total number of missing values
totalMissing = missingCount.sum()

# Calculate percentage of missing values
print("The SF Permits dataset contains", round(((totalMissing/totalCells) * 100), 2), "%", "missing values.")

# %%
def getMissingPercent(dataSet):
    sums = dataSet.isnull().sum()
    return (sums/dataSet.shape[0]).sort_values(ascending=False)

missing_percent = getMissingPercent(sfPermits)
missing_percent

# %% [markdown]
# ## Possible Solutions
# - Remove all rows containing NaN values
# - Remove all columns containing NaN values
# - Fill in the gaps with new data
# - Manually clean the dataset

# %% [markdown]
# ### Solution 1: remove all rows containing NaN values

# %%
remRows = sfPermits.dropna()
remRows

# %% [markdown]
# As you can see, this doesn't make any sense, as there would be no row left which contains data.

# %% [markdown]
# ### Solution 2: remove all columns containing NaN values

# %%
remCols = sfPermits.dropna(axis=1)
remCols.head()

# %%
print("Columns in original dataset: %d \n" % sfPermits.shape[1])
print("Columns with na's dropped: %d" % remCols.shape[1])

# %% [markdown]
# This solution also doesn't make sense, as there would be too few columns left for data exploration.

# %% [markdown]
# ### Solution 3: fill in the gaps with zeroes

# %%
imputeZeroes = sfPermits.fillna(method='ffill', axis=0).fillna("0")
print("Column count after filling the gaps: %d" % imputeZeroes.shape[1])
imputeZeroes.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-fdb6234acb25> in <module>
# ----> 1 imputeZeroes = sfPermits.fillna(method='ffill', axis=0).fillna("0")
#       2 print("Column count after filling the gaps: %d" % imputeZeroes.shape[1])
#       3 imputeZeroes.head()
#
# NameError: name 'sfPermits' is not defined

# %% [markdown]
# Now we would have no more NaN values left, but the data doesn't make sense anymore, so we should try to fill it with some reliable data.

# %% [markdown]
# ### Solution 4: manually clean the dataset

# %%
#First of all, let's drop all columns with at least 50% missing data

missing_percent.head(10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-d3e1074fa8f0> in <module>
#       1 #First of all, let's drop all columns with at least 50% missing data
#       2
# ----> 3 missing_percent.head(10)
#
# NameError: name 'missing_percent' is not defined

# %%
sfPermitsCopy = sfPermits.copy()

def dropColumn(columnName):
    sfPermitsCopy.drop(columnName, axis=1, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-5e17c29b1096> in <module>
# ----> 1 sfPermitsCopy = sfPermits.copy()
#       2
#       3 def dropColumn(columnName):
#       4     sfPermitsCopy.drop(columnName, axis=1, inplace=True)
#       5
#
# NameError: name 'sfPermits' is not defined

# %%
for i in range(len(missing_percent)):
    if missing_percent[i] > 0.5:
        dropColumn(missing_percent.index[i])
    else:
        break
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-9279b127fe6b> in <module>
# ----> 1 for i in range(len(missing_percent)):
#       2     if missing_percent[i] > 0.5:
#       3         dropColumn(missing_percent.index[i])
#       4     else:
#       5         break
#
# NameError: name 'missing_percent' is not defined

# %%
print("Column count after removing those columns: %d" % sfPermitsCopy.shape[1])
# Out:
# Column count after removing those columns: 34

# %%
sfPermitsCopy.head()
# Out:
#   Permit Number  Permit Type            Permit Type Definition  \
# 0  201505065519            4                      sign - erect
# 1  201604195146            4                      sign - erect
# 2  201605278609            3  additions alterations or repairs
# 3  201611072166            8            otc alterations permit
# 4  201611283529            6                       demolitions
#
#   Permit Creation Date Block  Lot  Street Number Street Name Street Suffix  \
# 0           05/06/2015  0326  023            140       Ellis            St
# 1           04/19/2016  0306  007            440       Geary            St
# 2           05/27/2016  0595  203           1647     Pacific            Av
# 3           11/07/2016  0156  011           1230     Pacific            Av
# 4           11/28/2016  0342  001            950      Market            St
#
#                                          Description  ... Plansets  \
# 0  ground fl facade: to erect illuminated, electr...  ...      2.0
# 1            remove (e) awning and associated signs.  ...      2.0
# 2                    installation of separating wall  ...      2.0
# 3           repair dryrot & stucco at front of bldg.  ...      2.0
# 4  demolish retail/office/commercial 3-story buil...  ...      2.0
#
#   Existing Construction Type Existing Construction Type Description  \
# 0                        3.0                          constr type 3
# 1                        3.0                          constr type 3
# 2                        1.0                          constr type 1
# 3                        5.0                         wood frame (5)
# 4                        3.0                          constr type 3
#
#   Proposed Construction Type Proposed Construction Type Description  \
# 0                        NaN                                    NaN
# 1                        NaN                                    NaN
# 2                        1.0                          constr type 1
# 3                        5.0                         wood frame (5)
# 4                        NaN                                    NaN
#
#    Supervisor District  Neighborhoods - Analysis Boundaries  Zipcode  \
# 0                  3.0                           Tenderloin  94102.0
# 1                  3.0                           Tenderloin  94102.0
# 2                  3.0                         Russian Hill  94109.0
# 3                  3.0                             Nob Hill  94109.0
# 4                  6.0                           Tenderloin  94102.0
#
#                                     Location      Record ID
# 0  (37.785719256680785, -122.40852313194863)  1380611233945
# 1   (37.78733980600732, -122.41063199757738)  1420164406718
# 2    (37.7946573324287, -122.42232562979227)  1424856504716
# 3   (37.79595867909168, -122.41557405519474)  1443574295566
# 4   (37.78315261897309, -122.40950883997789)   144548169992
#
# [5 rows x 34 columns]

# %%
print(getMissingPercent(sfPermitsCopy))
# Out:
# Permit Expiration Date                    0.260835
# Existing Units                            0.259115
# Proposed Units                            0.255963
# Existing Construction Type Description    0.218029
# Existing Construction Type                0.218029
# Proposed Construction Type Description    0.217004
# Proposed Construction Type                0.217004
# Number of Proposed Stories                0.215525
# Number of Existing Stories                0.215103
# Proposed Use                              0.213369
# Existing Use                              0.206707
# Estimated Cost                            0.191383
# Plansets                                  0.187577
# First Construction Document Date          0.075143
# Issued Date                               0.075113
# Revised Cost                              0.030498
# Street Suffix                             0.013917
# Neighborhoods - Analysis Boundaries       0.008673
# Supervisor District                       0.008632
# Zipcode                                   0.008627
# Location                                  0.008547
# Description                               0.001458
# Lot                                       0.000000
# Permit Type                               0.000000
# Permit Type Definition                    0.000000
# Permit Creation Date                      0.000000
# Block                                     0.000000
# Record ID                                 0.000000
# Street Number                             0.000000
# Street Name                               0.000000
# Current Status                            0.000000
# Current Status Date                       0.000000
# Filed Date                                0.000000
# Permit Number                             0.000000
# dtype: float64

# %%
#There are some more columns we can delete, as they are not important for the model

more_columns_to_delete = ['Existing Construction Type Description', #Just a description
                          'Proposed Construction Type Description', #Also
                          'Location', #Geocoordinates, ZIP code is better usable
                          'Description', #Another description
                          'Permit Type Definition', #Better use the permit type (numerical)
                          'Permit Number', #Just a number without important semantic
                          'Record ID' #Same reason as permit number
                          
                         ]

for column in more_columns_to_delete:
    dropColumn(column)
    
print("Column count after removing those columns: %d" % sfPermitsCopy.shape[1])
# Out:
# Column count after removing those columns: 27

# %%
# Now that we've got a clean dataset, we can start to impute missing values
# For the empty columns containing existing values we are going to use the proposed ones and drop the columns afterwards

sfPermitsCopy['Existing Use'].fillna(sfPermitsCopy['Proposed Use'], inplace=True)
sfPermitsCopy['Existing Units'].fillna(sfPermitsCopy['Proposed Units'], inplace=True)
sfPermitsCopy['Existing Construction Type'].fillna(sfPermitsCopy['Proposed Construction Type'], inplace=True)
sfPermitsCopy['Number of Existing Stories'].fillna(sfPermitsCopy['Number of Proposed Stories'], inplace=True)

sfPermitsCopy.drop('Proposed Use', axis = 1, inplace= True)
sfPermitsCopy.drop('Proposed Units', axis = 1, inplace= True)
sfPermitsCopy.drop('Proposed Construction Type', axis = 1, inplace= True)
sfPermitsCopy.drop('Number of Proposed Stories', axis = 1, inplace= True)


#Spalten hinzufügen, wo was verändert wurde
#Jahre splitten

# %%
pd.set_option('display.max_columns', 50)
sfPermitsCopy.sample(10)
# Out:
#         Permit Type Permit Creation Date  Block   Lot  Street Number  \
# 60635             3           09/10/2014   0479   027           1356
# 110430            8           01/04/2016   1276  001H            202
# 165042            3           07/21/2017   3622   004            818
# 79200             8           03/17/2015   1509   009            547
# 76487             8           02/20/2015   1923   023           1662
# 103125            8           10/21/2015   0738   049            851
# 109832            8           12/23/2015   0818   046            488
# 47606             8           05/12/2014   5523   007           3240
# 87148             8           05/29/2015  2823A   017              5
# 35831             8           01/08/2014   1857   030           1526
#
#        Street Name Street Suffix Current Status Current Status Date  \
# 60635     Chestnut            St         issued          05/04/2016
# 110430     Grattan            St       complete          05/13/2016
# 165042         Noe            St          filed          07/21/2017
# 79200         35th            Av         issued          03/31/2015
# 76487         21st            Av       complete          03/10/2015
# 103125    Van Ness            Av         issued          10/21/2015
# 109832        Fell            St          filed          12/23/2015
# 47606       Folsom            St       complete          05/14/2015
# 87148    Gladeview            Wy         issued          05/29/2015
# 35831         12th            Av         issued          01/08/2014
#
#         Filed Date Issued Date First Construction Document Date  \
# 60635   09/10/2014  05/04/2016                       05/04/2016
# 110430  01/04/2016  01/04/2016                       01/04/2016
# 165042  07/21/2017         NaN                              NaN
# 79200   03/17/2015  03/31/2015                       03/31/2015
# 76487   02/20/2015  02/20/2015                       02/20/2015
# 103125  10/21/2015  10/21/2015                       10/21/2015
# 109832  12/23/2015         NaN                              NaN
# 47606   05/12/2014  05/12/2014                       05/12/2014
# 87148   05/29/2015  05/29/2015                       05/29/2015
# 35831   01/08/2014  01/08/2014                       01/08/2014
#
#         Number of Existing Stories Permit Expiration Date  Estimated Cost  \
# 60635                          3.0             04/29/2017         45000.0
# 110430                         3.0             12/29/2016         45283.0
# 165042                         3.0                    NaN         20000.0
# 79200                          2.0             03/25/2016          7000.0
# 76487                          2.0             02/15/2016          1000.0
# 103125                         6.0             10/15/2016         17500.0
# 109832                         3.0                    NaN          4000.0
# 47606                          2.0             05/07/2015          8032.0
# 87148                          2.0             05/23/2016          6000.0
# 35831                          2.0             01/03/2015         12000.0
#
#         Revised Cost       Existing Use  Existing Units  Plansets  \
# 60635        45000.0         apartments             3.0       2.0
# 110430       45283.0         apartments             4.0       0.0
# 165042           NaN  1 family dwelling             1.0       2.0
# 79200         9000.0  1 family dwelling             1.0       2.0
# 76487         1000.0  1 family dwelling             1.0       0.0
# 103125       17500.0         apartments            32.0       0.0
# 109832        4000.0       retail sales             2.0       2.0
# 47606         8032.0  2 family dwelling             2.0       0.0
# 87148        21000.0  1 family dwelling             1.0       2.0
# 35831        12000.0  1 family dwelling             1.0       0.0
#
#         Existing Construction Type  Supervisor District  \
# 60635                          5.0                  2.0
# 110430                         5.0                  5.0
# 165042                         5.0                  8.0
# 79200                          5.0                  1.0
# 76487                          5.0                  4.0
# 103125                         3.0                  5.0
# 109832                         5.0                  5.0
# 47606                          5.0                  9.0
# 87148                          5.0                  7.0
# 35831                          5.0                  7.0
#
#        Neighborhoods - Analysis Boundaries  Zipcode
# 60635                               Marina  94123.0
# 110430                      Haight Ashbury  94117.0
# 165042                          Noe Valley  94114.0
# 79200                       Outer Richmond  94121.0
# 76487                      Sunset/Parkside  94122.0
# 103125                    Western Addition  94109.0
# 109832                        Hayes Valley  94102.0
# 47606                       Bernal Heights  94110.0
# 87148                           Twin Peaks  94131.0
# 35831                         Inner Sunset  94122.0

# %%
# Afterwards we are going to fill numerical values with the mean and character values with the mode of the dataset

mean = [
    'Revised Cost',
    'Estimated Cost'
]

for column in mean:
    sfPermitsCopy[column].fillna(sfPermitsCopy[column].mean(skipna=True), inplace=True)

mode = [
    'Existing Construction Type',
    'Existing Units',
    'Existing Use',
    'Plansets',
    'Number of Existing Stories',
]

for column in mode:
    sfPermitsCopy[column].fillna(sfPermitsCopy[column].mode()[0], inplace = True)

# %%
#Lastly we drop all rows still containing NaN values. There should be enough left to do some exploration

clean_dataset = sfPermitsCopy.dropna()

print("Rows left: %d" % len(clean_dataset))
# Out:
# Rows left: 143814

# %%
clean_dataset.to_csv("./Building_Permits_Clean.csv")
clean_dataset.sample(10)
# Out:
#         Permit Type Permit Creation Date Block   Lot  Street Number  \
# 24731             8           09/13/2013  3718   026            201
# 184653            8           10/03/2017  1227   024            600
# 158415            8           06/02/2017  0337   007            308
# 105516            8           11/10/2015  7053   018            685
# 163000            8           01/29/2016  1085   039            838
# 150886            8           03/01/2017  5296  024A           1631
# 50982             8           06/11/2014  5975  003B            645
# 10109             8           04/19/2013  0246   001           1100
# 54317             8           07/10/2014  1369   011            195
# 110929            8           01/08/2016  0295   016            345
#
#        Street Name Street Suffix Current Status Current Status Date  \
# 24731      Mission            St       complete          11/26/2013
# 184653     Stanyan            St         issued          10/03/2017
# 158415        Turk            St         issued          06/02/2017
# 105516    Lakeview            Av       complete          11/19/2015
# 163000        Anza            St       complete          07/17/2017
# 150886    La Salle            Av       complete          03/06/2017
# 50982      Bowdoin            St       complete          04/10/2017
# 10109   California            St       complete          05/22/2013
# 54317         09th            Av       complete          03/24/2017
# 110929    Stockton            St       complete          07/27/2016
#
#         Filed Date Issued Date First Construction Document Date  \
# 24731   09/13/2013  09/13/2013                       09/13/2013
# 184653  10/03/2017  10/03/2017                       10/03/2017
# 158415  06/02/2017  06/02/2017                       06/02/2017
# 105516  11/10/2015  11/10/2015                       11/10/2015
# 163000  01/29/2016  05/05/2016                       05/05/2016
# 150886  03/01/2017  03/01/2017                       03/01/2017
# 50982   06/11/2014  06/11/2014                       06/11/2014
# 10109   04/19/2013  04/19/2013                       04/19/2013
# 54317   07/10/2014  08/08/2014                       08/08/2014
# 110929  01/08/2016  01/11/2016                       01/11/2016
#
#         Number of Existing Stories Permit Expiration Date  Estimated Cost  \
# 24731                         31.0             09/08/2014         19500.0
# 184653                         3.0             02/03/2018          5000.0
# 158415                         2.0             05/28/2018             1.0
# 105516                         1.0             11/04/2016          3500.0
# 163000                         4.0             04/30/2017         85000.0
# 150886                         2.0             02/24/2018          6700.0
# 50982                          2.0             05/26/2017        190000.0
# 10109                          3.0             04/14/2014          1000.0
# 54317                          4.0             08/03/2015         30000.0
# 110929                        35.0             12/26/2018         20000.0
#
#         Revised Cost       Existing Use  Existing Units  Plansets  \
# 24731        19500.0             office             0.0       2.0
# 184653        5000.0         apartments            30.0       2.0
# 158415           1.0         apartments            20.0       2.0
# 105516        3500.0  1 family dwelling             1.0       0.0
# 163000       85000.0         apartments             9.0       2.0
# 150886        6700.0  1 family dwelling             1.0       0.0
# 50982       190000.0  1 family dwelling             1.0       0.0
# 10109         1500.0             church             0.0       2.0
# 54317        30000.0         apartments            12.0       2.0
# 110929      250000.0       retail sales           685.0       2.0
#
#         Existing Construction Type  Supervisor District  \
# 24731                          1.0                  6.0
# 184653                         5.0                  5.0
# 158415                         5.0                  6.0
# 105516                         5.0                 11.0
# 163000                         5.0                  1.0
# 150886                         5.0                 10.0
# 50982                          5.0                  9.0
# 10109                          2.0                  3.0
# 54317                          5.0                  1.0
# 110929                         1.0                  3.0
#
#        Neighborhoods - Analysis Boundaries  Zipcode
# 24731       Financial District/South Beach  94105.0
# 184653                      Haight Ashbury  94117.0
# 158415                          Tenderloin  94102.0
# 105516          Oceanview/Merced/Ingleside  94112.0
# 163000                   Lone Mountain/USF  94118.0
# 150886               Bayview Hunters Point  94124.0
# 50982                              Portola  94134.0
# 10109                             Nob Hill  94108.0
# 54317                       Inner Richmond  94118.0
# 110929      Financial District/South Beach  94108.0

# %% [markdown]
# ## Task B Exploration
# - Explore the data. Which columns correlate strongly with the "Current Status" column? How do other columns correlate to each other?
# - Describe problems with "Current Status" as a target column to predict. Can you construct a better target column?

# %% [markdown]
# ## Task C Prediction
# -  Predict the "Current Status" or your substitute column from B from the other columns.
# - Drop unessecary columns
# - Construct one-hot encoded dummy columns
# - Choose the Predictor of your choice

# %% [markdown]
# ## Task D Challenges
# - Describe challenges you faced during A, B and C and how you solved it.
